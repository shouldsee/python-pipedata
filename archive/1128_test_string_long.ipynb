# %%
# %%writefile tests/example_string_long.py
from pipeline_tracker import RawNode as Node
from pipeline_tracker import TrackedFile, InputTrackedFile, index_file_flush
import os
_node = Node
numberFile = InputTrackedFile('number.txt')
letterFile = InputTrackedFile('letter.txt')
import time
# _output_kw = Node.from_func
@Node.from_func({
    "OUT":TrackedFile("out5.txt"),
#     "BAM":TrackedFile( "test.fastq.bam"  )
})
def out5(  self, numberFile, letterFile ):
    '''
    some doc
    '''
    if self.changed_upstream() or self.force:
        print("RUNNING:%s"%self)
        number = numberFile().open('r').read().strip()
        letter = letterFile().open('r').read().strip()
#         lines = list( INPUT_FILE().open('r') )
        with self.output_kw['OUT'].open("w") as f:
            f.write( 5 * (number+letter)+'\n')
    else:
        print("SKIPPING:%s"%self)
        pass
    return


@Node.from_func({
    "OUT":TrackedFile("out10.txt"),
#     "BAM":TrackedFile( "test.fastq.bam"  )
})
def out10(  self, numberFile, letterFile ):
    '''
    some doc
    '''
    if self.changed_upstream() or self.force:
        print("RUNNING:%s"%self)
        number = numberFile().open('r').read().strip()
        letter = letterFile().open('r').read().strip()
#         lines = list( INPUT_FILE().open('r') )
        with self['OUT'].open("w") as f:
            f.write( 10 * (number+letter)+'\n')
        self['OUT'].index_update()   
    else:
        print("SKIPPING:%s"%self)
        pass
    return

@Node.from_func({
    "OUT":TrackedFile("out15.txt"),
#     "BAM":TrackedFile( "test.fastq.bam"  )
})
def out15(  self, numberFile, letterFile ):
    '''
    some doc
    '''
    if self.changed_upstream() or self.force:
        print("RUNNING:%s"%self)
        number = numberFile().open('r').read().strip()
        letter = letterFile().open('r').read().strip()
#         lines = list( INPUT_FILE().open('r') )
        with self.output_kw['OUT'].open("w") as f:
            f.write( 15 * (number+letter)+'\n')
        self['OUT'].index_update()   
#         index_file_update(self['OUT'])
    else:
        print("SKIPPING:%s"%self)
        pass
    return

@Node.from_func({
    'OUT':TrackedFile('combined.txt')
})
def make_combined( self, out5, out10, out15, ):
    if self.changed_upstream() or self.force:
        lines = []
        [ lines.extend(list(x()['OUT'].open('r'))) for x in [out5,
                                                             out10,out15
                                                            ]]
        print out5()['OUT'].path
        print lines
        with self['OUT'].open('w') as f:
            map(f.write,lines)
        self['OUT'].index_update()   
    else:
        print("SKIPPING:%s"%self)
#     make_bam()
    return 1


if __name__ == '__main__':
    
    os.chdir("tests/")
    make_combined()
    index_file_flush("./test.index")
# Out:
# Overwriting tests/example_string_long.py

# %%
# %%bash
# set -x
# exec 2>&1
#
# mkdir -p tests
# ln pipeline_tracker.py tests -f
# rm -f tests/test.index tests/out*.txt
#
# echo "1"> tests/number.txt;
# echo a>tests/letter.txt;
#
# time python2 tests/example_string_long.py
#
#
# time python2 tests/example_string_long.py
#
# echo "2">tests/number.txt;
# echo b>tests/letter.txt;
#
# time python2 tests/example_string_long.py
# Out:
# + mkdir -p tests
# + ln pipeline_tracker.py tests -f
# + rm -f tests/test.index tests/out10.txt tests/out15.txt tests/out5.txt
# + echo 1
# + echo a
# + python2 tests/example_string_long.py
# RUNNING:<Node with func:<function out5 at 0x7f4e872d6c08>>
# RUNNING:<Node with func:<function out10 at 0x7f4e872d6668>>
# RUNNING:<Node with func:<function out15 at 0x7f4e872d6ed8>>
# RUNNING:<Node with func:<function out5 at 0x7f4e872d6c08>>
# out5.txt
# ['1a1a1a1a1a\n', '1a1a1a1a1a1a1a1a1a1a\n', '1a1a1a1a1a1a1a1a1a1a1a1a1a1a1a\n']
#
# real	0m0.071s
# user	0m0.068s
# sys	0m0.000s
# + python2 tests/example_string_long.py
# SKIPPING:<Node with func:<function out5 at 0x7fdd287dfc08>>
# SKIPPING:<Node with func:<function out10 at 0x7fdd287df668>>
# SKIPPING:<Node with func:<function out15 at 0x7fdd287dfed8>>
# SKIPPING:<Node with func:<function out5 at 0x7fdd287dfc08>>
# out5.txt
# ['1a1a1a1a1a\n', '1a1a1a1a1a1a1a1a1a1a\n', '1a1a1a1a1a1a1a1a1a1a1a1a1a1a1a\n']
#
# real	0m0.068s
# user	0m0.048s
# sys	0m0.020s
# + echo 2
# + echo b
# + python2 tests/example_string_long.py
# RUNNING:<Node with func:<function out5 at 0x7f6e0db7cc08>>
# RUNNING:<Node with func:<function out10 at 0x7f6e0db7c668>>
# RUNNING:<Node with func:<function out15 at 0x7f6e0db7ced8>>
# RUNNING:<Node with func:<function out5 at 0x7f6e0db7cc08>>
# out5.txt
# ['2b2b2b2b2b\n', '2b2b2b2b2b2b2b2b2b2b\n', '2b2b2b2b2b2b2b2b2b2b2b2b2b2b2b\n']
#
# real	0m0.063s
# user	0m0.044s
# sys	0m0.016s
# + exec

# %%
import pymisca.ext as pyext
print pyext.shellexec(
'''
set -x
exec 2>&1

mkdir -p tests
ln pipeline_tracker.py tests -f 
rm -f tests/test.index tests/out*.txt

echo "1"> tests/number.txt; 
echo a>tests/letter.txt; 

time python2 tests/example_string_long.py


time python2 tests/example_string_long.py

echo "2">tests/number.txt; 
echo b>tests/letter.txt; 

time python2 tests/example_string_long.py
'''
)
#     make_bam()
#     make_csv()
#     print("[middle]",middle())
# Out:
# [CMD]
# set -x
# exec 2>&1
#
# mkdir -p tests
# ln pipeline_tracker.py tests -f
# rm -f tests/test.index tests/out*.txt
#
# echo "1"> tests/number.txt;
# echo a>tests/letter.txt;
#
# time python2 tests/example_string_long.py
#
#
# time python2 tests/example_string_long.py
#
# echo "2">tests/number.txt;
# echo b>tests/letter.txt;
#
# time python2 tests/example_string_long.py
# + mkdir -p tests
# + ln pipeline_tracker.py tests -f
# + rm -f tests/test.index tests/out10.txt tests/out15.txt tests/out5.txt
# + echo 1
# + echo a
# + python2 tests/example_string_long.py
# RUNNING:<Node with func:<function out5 at 0x7fc2061adc08>>
# RUNNING:<Node with func:<function out10 at 0x7fc2061ad668>>
# RUNNING:<Node with func:<function out15 at 0x7fc2061aded8>>
# RUNNING:<Node with func:<function out5 at 0x7fc2061adc08>>
# out5.txt
# ['1a1a1a1a1a\n', '1a1a1a1a1a1a1a1a1a1a\n', '1a1a1a1a1a1a1a1a1a1a1a1a1a1a1a\n']
#
# real	0m0.086s
# user	0m0.076s
# sys	0m0.004s
# + python2 tests/example_string_long.py
# SKIPPING:<Node with func:<function out5 at 0x7fdf6112ec08>>
# SKIPPING:<Node with func:<function out10 at 0x7fdf6112e668>>
# SKIPPING:<Node with func:<function out15 at 0x7fdf6112eed8>>
# SKIPPING:<Node with func:<function out5 at 0x7fdf6112ec08>>
# out5.txt
# ['1a1a1a1a1a\n', '1a1a1a1a1a1a1a1a1a1a\n', '1a1a1a1a1a1a1a1a1a1a1a1a1a1a1a\n']
#
# real	0m0.061s
# user	0m0.044s
# sys	0m0.016s
# + echo 2
# + echo b
# + python2 tests/example_string_long.py
# RUNNING:<Node with func:<function out5 at 0x7fadff1b6c08>>
# RUNNING:<Node with func:<function out10 at 0x7fadff1b6668>>
# RUNNING:<Node with func:<function out15 at 0x7fadff1b6ed8>>
# RUNNING:<Node with func:<function out5 at 0x7fadff1b6c08>>
# out5.txt
# ['2b2b2b2b2b\n', '2b2b2b2b2b2b2b2b2b2b\n', '2b2b2b2b2b2b2b2b2b2b2b2b2b2b2b\n']
#
# real	0m0.075s
# user	0m0.068s
# sys	0m0.004s
